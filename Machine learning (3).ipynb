# %%
## 🌦️ Project Purpose

##This project goes beyond just forecasting temperature. It aims to **help people detect unusual or extreme patterns in daily weather** — acting as an early signal for days that might require extra caution or preparedness.

##By neural networks to analyze historical weather data, the model can detect trends and forecast upcoming conditions. This information could assist in:
##- Planning travel or outdoor events
##- Anticipating unusual temperature spikes or drops
##- Supporting decision-making in sensitive environments (schools, construction, elderly care, etc.)

# !pip install --upgrade tensorflow

import pandas as pd
df = pd.read_csv("Daily_Weather_Data.csv")
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'], utc= True)
df.set_index('Formatted Date', inplace = True)
df.sort_index(inplace = True)
df.head()
# Out:
# Requirement already satisfied: tensorflow in c:\users\omar7\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (3.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (3.9.2)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\omar7\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\omar7\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\omar7\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\omar7\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\omar7\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\omar7\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\omar7\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\omar7\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\omar7\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\omar7\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\omar7\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\omar7\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\omar7\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\omar7\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\omar7\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\omar7\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
#                            Temperature (C)  Apparent Temperature (C)  \
# Formatted Date
# 2005-12-31 00:00:00+00:00         0.577778                 -4.050000
# 2006-01-01 00:00:00+00:00         4.075000                 -0.174537
# 2006-01-02 00:00:00+00:00         5.263194                  1.808796
# 2006-01-03 00:00:00+00:00         2.340509                  0.445370
# 2006-01-04 00:00:00+00:00         2.251852                 -0.663194
#
#                            Humidity  Wind Speed (km/h)  \
# Formatted Date
# 2005-12-31 00:00:00+00:00  0.890000          17.114300
# 2006-01-01 00:00:00+00:00  0.817083          21.229192
# 2006-01-02 00:00:00+00:00  0.847083          17.824713
# 2006-01-03 00:00:00+00:00  0.897083           7.726658
# 2006-01-04 00:00:00+00:00  0.906667          12.152817
#
#                            Wind Bearing (degrees)  Visibility (km)  \
# Formatted Date
# 2005-12-31 00:00:00+00:00              140.000000         9.982000
# 2006-01-01 00:00:00+00:00              142.750000        11.348487
# 2006-01-02 00:00:00+00:00              164.583333         8.492079
# 2006-01-03 00:00:00+00:00              252.541667         9.223958
# 2006-01-04 00:00:00+00:00               35.000000         8.352546
#
#                            Loud Cover  Pressure (millibars)
# Formatted Date
# 2005-12-31 00:00:00+00:00           0           1016.660000
# 2006-01-01 00:00:00+00:00           0           1011.985000
# 2006-01-02 00:00:00+00:00           0           1010.384167
# 2006-01-03 00:00:00+00:00           0           1021.170833
# 2006-01-04 00:00:00+00:00           0            981.770833

# %%
df = pd.read_csv("Daily_Weather_Data.csv")
df['Formatted Date'] = pd.to_datetime(df['Formatted Date'], utc=True)
df.set_index('Formatted Date', inplace=True)
df.sort_index(inplace=True)

# Resample to daily average
df_daily = df.resample('D').mean()

# %%
from sklearn.preprocessing import MinMaxScaler
visibility = df[['Visibility (km)']].copy()

scaler = MinMaxScaler()
visibility_scaled = scaler.fit_transform(visibility)

print(visibility_scaled[:5])
# Out:
# [[0.62681663]
#  [0.71262479]
#  [0.53325751]
#  [0.57921564]
#  [0.52449556]]

# %%
import numpy as np
def create_sequences(data, window_size=7):
    X,y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i+window_size])
        y.append(data[i+window_size])
    return np.array(X), np.array(y)
X, y = create_sequences(visibility_scaled, window_size=7)

print("X shape:", X.shape)
print("Y shape:", y.shape)
# Out:
# X shape: (4012, 7, 1)
# Y shape: (4012, 1)

# %%
split_index = int(0.8*len(X))
X_train = X[:split_index]
y_train = y[:split_index]
X_test = X[split_index:]
y_test = y[split_index:]
print("X_train:",X_train.shape)
print("y_train:",y_train.shape)
print("X_test:",X_test.shape)
print("y_test:",y_test.shape)
# Out:
# X_train: (3209, 7, 1)
# y_train: (3209, 1)
# X_test: (803, 7, 1)
# y_test: (803, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
model = Sequential()
model.add(LSTM(units =50, activation = 'tanh', input_shape=(X_train.shape[1],X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer ='adam', loss ='mse')
history = model.fit(X_train,y_train,epochs=20,batch_size=32,validation_data=(X_test,y_test))
# Out:
# Epoch 1/20
# C:\Users\omar7\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1823 - val_loss: 0.0381
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0213 - val_loss: 0.0365
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0215 - val_loss: 0.0351
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0206 - val_loss: 0.0336
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0194 - val_loss: 0.0328
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0189 - val_loss: 0.0311
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - val_loss: 0.0289
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0177 - val_loss: 0.0274
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0177 - val_loss: 0.0259
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0164 - val_loss: 0.0247
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0161 - val_loss: 0.0247
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0159 - val_loss: 0.0231
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0153 - val_loss: 0.0234
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0155 - val_loss: 0.0233
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0147 - val_loss: 0.0223
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0152 - val_loss: 0.0223
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0152 - val_loss: 0.0230
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0153 - val_loss: 0.0223
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0145 - val_loss: 0.0225
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0150 - val_loss: 0.0222

# %%
import matplotlib.pyplot as plt


y_pred = model.predict(X_test)

y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test)

plt.figure(figsize=(12, 6))
plt.plot(y_test_inv, label="Actual visbility")
plt.plot(y_pred_inv, label="Predicted visbility")
plt.title("Actual vs Predicted visbility")
plt.xlabel("Time (Days)")
plt.ylabel("Visbility (KM)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mse = mean_squared_error(y_test, y_pred_esn)

print("RMSE:", rmse)
print("MAE:", mae)
print("MSE:",mse)
# Out:
# RMSE: 2.3747597457427045
# MAE: 1.8368147374240158
# MSE: 0.023402111409860107

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(units=50, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# C:\Users\omar7\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2242 - val_loss: 0.0403
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0224 - val_loss: 0.0385
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0212 - val_loss: 0.0370
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0207 - val_loss: 0.0350
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0206 - val_loss: 0.0333
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0196 - val_loss: 0.0316
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0186 - val_loss: 0.0303
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0172 - val_loss: 0.0286
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0172 - val_loss: 0.0271
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166 - val_loss: 0.0262
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0165 - val_loss: 0.0252
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0155 - val_loss: 0.0250
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0164 - val_loss: 0.0235
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0155 - val_loss: 0.0240
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0151 - val_loss: 0.0234
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - val_loss: 0.0225
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0151 - val_loss: 0.0224
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0147 - val_loss: 0.0223
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0151 - val_loss: 0.0235
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0139 - val_loss: 0.0228

# %%
model.save("Machine_learning.keras")

# %%
threshold = 3.0  # define your own logic
anomalies = np.abs(y_pred_inv - y_test_inv) > threshold
print("⚠️ Unusual days detected:", np.sum(anomalies))
# Out:
# ⚠️ Unusual days detected: 154

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout

# Bi-LSTM Model
bi_lstm_model = Sequential()
bi_lstm_model.add(Bidirectional(LSTM(units=50, activation='tanh'), input_shape=(X_train.shape[1], X_train.shape[2])))
bi_lstm_model.add(Dropout(0.2))
bi_lstm_model.add(Dense(1))

bi_lstm_model.compile(optimizer='adam', loss='mse')

# Training
history_bi_lstm = bi_lstm_model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1
)

# Evaluation
loss_bi_lstm = bi_lstm_model.evaluate(X_test, y_test)
print("Bi-LSTM Test Loss (MSE):", loss_bi_lstm)
# Out:
# Epoch 1/20
# C:\Users\omar7\anaconda3\Lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 0.0779 - val_loss: 0.0344
# Epoch 2/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0232 - val_loss: 0.0332
# Epoch 3/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0221 - val_loss: 0.0324
# Epoch 4/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0211 - val_loss: 0.0302
# Epoch 5/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0205 - val_loss: 0.0289
# Epoch 6/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0192 - val_loss: 0.0288
# Epoch 7/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0194 - val_loss: 0.0270
# Epoch 8/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0190 - val_loss: 0.0266
# Epoch 9/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0198 - val_loss: 0.0259
# Epoch 10/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0181 - val_loss: 0.0257
# Epoch 11/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - val_loss: 0.0244
# Epoch 12/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0172 - val_loss: 0.0246
# Epoch 13/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0169 - val_loss: 0.0235
# Epoch 14/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0173 - val_loss: 0.0229
# Epoch 15/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0163 - val_loss: 0.0227
# Epoch 16/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0155 - val_loss: 0.0226
# Epoch 17/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0158 - val_loss: 0.0224
# Epoch 18/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0174 - val_loss: 0.0242
# Epoch 19/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0173 - val_loss: 0.0231
# Epoch 20/20
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0165 - val_loss: 0.0223
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0245
# Bi-LSTM Test Loss (MSE): 0.02227400243282318

# %%
import numpy as np

class SimpleESN:
    def __init__(self, input_dim, reservoir_size=100, spectral_radius=0.95, sparsity=0.2):
        self.input_dim = input_dim
        self.reservoir_size = reservoir_size
        self.spectral_radius = spectral_radius
        self.sparsity = sparsity

        # Initialize weights
        self.Win = np.random.rand(reservoir_size, input_dim) * 2 - 1
        W = np.random.rand(reservoir_size, reservoir_size) - 0.5
        W[np.random.rand(*W.shape) > sparsity] = 0
        radius = np.max(np.abs(np.linalg.eigvals(W)))
        self.W = W * (spectral_radius / radius)

    def _update(self, state, u):
        return np.tanh(np.dot(self.Win, u) + np.dot(self.W, state))

    def fit(self, X, y):
        X = X.squeeze()
        states = []
        state = np.zeros(self.reservoir_size)

        for i in range(len(X)):
            state = self._update(state, X[i])
            states.append(state)

        states = np.vstack(states)
        self.Wout = np.linalg.pinv(states).dot(y)
        return self

    def predict(self, X):
        X = X.squeeze()
        states = []
        state = np.zeros(self.reservoir_size)

        for i in range(len(X)):
            state = self._update(state, X[i])
            states.append(state)

        states = np.vstack(states)
        return states.dot(self.Wout)

# %%
# Reshape for ESN
X_train_flat = X_train.reshape((X_train.shape[0], -1))
X_test_flat = X_test.reshape((X_test.shape[0], -1))

# Train and predict
esn = SimpleESN(input_dim=X_train_flat.shape[1], reservoir_size=100)
esn.fit(X_train_flat, y_train)
y_pred_esn = esn.predict(X_test_flat)

# Evaluate
from sklearn.metrics import mean_squared_error
mse_esn = mean_squared_error(y_test, y_pred_esn)
print("Echo State Network Test MSE:", mse_esn)
# Out:
# Echo State Network Test MSE: 0.023402111409860107

# %%
import matplotlib.pyplot as plt

# Bi-LSTM predictions
y_pred_bilstm = bi_lstm_model.predict(X_test)

# Plot actual vs predicted for Bi-LSTM
plt.figure(figsize=(12, 5))
plt.plot(y_test, label='Actual')
plt.plot(y_pred_bilstm, label='Bi-LSTM Predicted')
plt.title("Bi-Directional LSTM - Actual vs Predicted")
plt.xlabel("Time")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %%
from sklearn.metrics import mean_squared_error

mse_bilstm = mean_squared_error(y_test, y_pred_bilstm)
print(f"Bi-LSTM Test MSE: {mse_bilstm:.4f}")
# Out:
# Bi-LSTM Test MSE: 0.0223

# %%
# Plot actual vs predicted for ESN
plt.figure(figsize=(12, 5))
plt.plot(y_test, label='Actual')
plt.plot(y_pred_esn, label='ESN Predicted')
plt.title("Echo State Network - Actual vs Predicted")
plt.xlabel("Time")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mse_esn = mean_squared_error(y_test, y_pred_esn)
print(f"ESN Test MSE:     {mse_esn:.4f}")
# Out:
# ESN Test MSE:     0.0234

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# %%
# Bi-LSTM metrics
mse_bilstm = mean_squared_error(y_test, y_pred_bilstm)
rmse_bilstm = np.sqrt(mse_bilstm)
mae_bilstm = mean_absolute_error(y_test, y_pred_bilstm)

# ESN metrics
mse_esn = mean_squared_error(y_test, y_pred_esn)
rmse_esn = np.sqrt(mse_esn)
mae_esn = mean_absolute_error(y_test, y_pred_esn)

# %%
import pandas as pd

results_df = pd.DataFrame({
    "Model": ["LSTM","Bi-LSTM", "Echo State Network"],
    "RMSE": [rmse,rmse_bilstm, rmse_esn],
    "MAE": [mae,mae_bilstm, mae_esn],
    "MSE": [mse,mse_bilstm, mse_esn]
})


print("Model Comparison:\n")
print(results_df)
# Out:
# Model Comparison:
#
#                 Model      RMSE       MAE       MSE
# 0                LSTM  2.374760  1.836815  0.023402
# 1             Bi-LSTM  0.149245  0.115233  0.022274
# 2  Echo State Network  0.152977  0.116228  0.023402

# %%
print("Model Comparison:\n")
print(results_df)

# Optional plot
results_df.set_index("Model")[["RMSE", "MAE"]].plot(kind="bar", figsize=(8, 5), title="Model Error Comparison", grid=True)
plt.ylabel("Error")
plt.tight_layout()
plt.show()
# Out:
# Model Comparison:
#
#                 Model      RMSE       MAE       MSE
# 0                LSTM  2.374760  1.836815  0.023402
# 1             Bi-LSTM  0.149245  0.115233  0.022274
# 2  Echo State Network  0.152977  0.116228  0.023402
